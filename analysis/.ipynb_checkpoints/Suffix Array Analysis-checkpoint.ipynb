# %% [markdown]
# # Suffix Array Algorithms Analysis
#
#
# This notebook summarizes analysis for certain algorithms that build the [suffix array](
# https://en.wikipedia.org/wiki/Suffix_array) data structure, classified according to their complexities.
#
# 1. **Brute Force** - *O(n^2 log n)*
# 2. **Radix Sort** - *O(n log^2 n)*
# 3. **Counting Sort** - *O(n log n)*
# 4. **DC3 Algorithm** - *O(kn)*
#
# Conclusion summary:
# - Brute Force special case is best for all (letters == 1).
# - Brute Force average complexity is inversely proportional to the increase of letters if (letters >= 2).
# - Brute Force is **best** for small cases (length <= 100 and letters >= 3) in terms of average complexity. The randomized pruning deals with the least overhead that's why it's fast.
# - Counting Sort is **best** for small binary cases (length <= 100 and letters == 2).
# - DC3 is **best** for medium cases (100 <= length <= 1000) with (2 <= letters < 10).
# - Brute Force is **best** for medium cases (100 <= length <= 1000) with (letters >= 10).
# - DC3 is **best** for all large test cases (length > 1000) with (letters >= 2).
# - Counting Sort has the same best case and worst case *O(n log n)* complexity.
# - Counting Sort is better for small number of letters.
# - Radix Sort has the worst time complexity.

# %%
# suffix array import
from progvar.strings.suffix import SuffixArray

# %%
# suffix array examples
sa = SuffixArray('abaab', algo='radix sort')
print sa
for i in sa:
    print sa.suffix(sa.position[i])
# Out:
# [5, 2, 3, 0, 4, 1]
# $
# aab$
# ab$
# abaab$
# b$
# baab$

# %%
from progvar.strings.utils import random_text
from time import time

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
mpl.style.use('ggplot')

def test(trials=10, text_length=10000, letters=5, exclude=['default']):
    
    # increment length every trial
    lengths = range(text_length // trials, text_length + 1, text_length // trials)
    trial_text = [random_text(length=length, letters=letters) for length in lengths]
    
    def perform_algorithm(algorithm):
        
        trials = []
        suffix_arrays = []

        # profile time
        time_elapsed = 0
        total_text_length = 0
        total_letters = set()


        for text in trial_text:
            # get median for small test cases to avoid anomalies
            timer = []
            for i in xrange(10 if text_length <= 3000 else 1):
                time_start = time()
                result = SuffixArray(text, algo=algorithm)
                timer.append(time() - time_start)
            
            timer.sort()

            # collect time statistics
            
            delta_time = np.median(timer)
            time_elapsed += delta_time

            # collect text statistics
            total_text_length += len(text)
            total_letters.update(list(text))

            # append to results
            trials.append(delta_time * 1000)
            suffix_arrays.append(result)


        time_per_trial = time_elapsed / len(trial_text)
        statistics = {
            'algorithm': algorithm,
            '# of trials': len(trial_text),
            'total time (ms)': time_elapsed * 1000,
            'average time per trial': time_per_trial * 1000,
            'letters': len(total_letters),
            'length': total_text_length / len(trial_text),
        }
        return trials, statistics, suffix_arrays
    
    algorithms_used = []
    all_trials = []
    all_statistics = []
    all_suffix_arrays = []
    
    for algorithm in SuffixArray.algorithms:
        
        if algorithm in exclude:
            continue
            
        trials, statistics, suffix_array = perform_algorithm(algorithm)
        
        algorithms_used.append(algorithm)
        all_trials.append(trials)
        all_statistics.append(statistics)
        all_suffix_arrays.append(suffix_array)
    
    n = len(all_trials)
    for algo, sa in zip(algorithms_used, all_suffix_arrays):
        for algo2, sa2 in zip(algorithms_used, all_suffix_arrays):
            if algo < algo2 and sa != sa2:
                print "WARNING! %s and %s have different suffix arrays!" % (algo, algo2)
    
    algo_trial = [{} for i in xrange(len(all_trials[0]))]
    for algo, trial in zip(algorithms_used, all_trials):
        for j in xrange(len(trial)):
            algo_trial[j][algo] = trial[j]
            
    #plt.show()
    
    all_statistics.sort(key=lambda stat: stat['total time (ms)'])
    from IPython.display import display, HTML
    display(pd.DataFrame(all_statistics, columns=('algorithm', 'total time (ms)')))
    
    df = pd.DataFrame(algo_trial, columns=algorithms_used, index=lengths)
    df.plot(kind='area', stacked=False, color=['r', 'g', 'k', 'w'])
    plt.show()


def perform_tests(n):
    letter_counts = [1, 2, 5, 10, 26, 50]
    for letters in letter_counts:
        print letters, 'letters:'
        test(trials=10, text_length=n, letters=letters)

# %% [markdown]
# # # Small Test Cases (n <= 100)

# %%
perform_tests(n=100)
# Out:
# 1 letters:
#        algorithm  total time (ms)
# 0          brute         0.809550
# 1  counting sort         3.076553
# 2            dc3         5.264282
# 3     radix sort         5.744934
# 2 letters:
#        algorithm  total time (ms)
# 0  counting sort         3.070831
# 1          brute         3.119588
# 2            dc3         4.039764
# 3     radix sort         5.663276
# 5 letters:
#        algorithm  total time (ms)
# 0          brute         2.284765
# 1  counting sort         3.018022
# 2            dc3         3.565669
# 3     radix sort         4.233718
# 10 letters:
#        algorithm  total time (ms)
# 0          brute         2.067566
# 1  counting sort         2.948880
# 2            dc3         3.250003
# 3     radix sort         3.351450
# 26 letters:
#        algorithm  total time (ms)
# 0          brute         1.920104
# 1            dc3         2.590179
# 2     radix sort         2.779245
# 3  counting sort         2.882004
# 50 letters:
# ...

# %% [markdown]
# ## Medium Test Cases (100 <= n <= 1000)

# %%
perform_tests(n=1000)
# Out:
# 1 letters:
#        algorithm  total time (ms)
# 0          brute         6.235480
# 1  counting sort        40.515780
# 2            dc3        46.450734
# 3     radix sort        67.227840
# 2 letters:
#        algorithm  total time (ms)
# 0            dc3        37.653327
# 1  counting sort        39.203525
# 2          brute        58.950901
# 3     radix sort        72.390795
# 5 letters:
#        algorithm  total time (ms)
# 0            dc3        32.007098
# 1          brute        36.927938
# 2  counting sort        38.261414
# 3     radix sort        58.743477
# 10 letters:
#        algorithm  total time (ms)
# 0            dc3        32.269239
# 1          brute        32.625079
# 2  counting sort        38.626909
# 3     radix sort        50.469518
# 26 letters:
#        algorithm  total time (ms)
# 0          brute        27.972341
# 1            dc3        32.609463
# 2  counting sort        38.253188
# 3     radix sort        40.157318
# 50 letters:
# ...

# %% [markdown]
# ## Large Test Cases (1000 <= n <= 10000)

# %%
perform_tests(n=10000)
# Out:
# 1 letters:
#        algorithm  total time (ms)
# 0          brute        59.540272
# 1            dc3       484.224081
# 2  counting sort       542.954445
# 3     radix sort       879.543543
# 2 letters:
#        algorithm  total time (ms)
# 0            dc3       386.765003
# 1  counting sort       596.640825
# 2     radix sort       888.445854
# 3          brute      1031.134844
# 5 letters:
#        algorithm  total time (ms)
# 0            dc3       369.494200
# 1          brute       596.363068
# 2  counting sort       605.723381
# 3     radix sort       761.053085
# 10 letters:
#        algorithm  total time (ms)
# 0            dc3       325.416803
# 1          brute       501.285076
# 2  counting sort       603.825808
# 3     radix sort       681.349754
# 26 letters:
#        algorithm  total time (ms)
# 0            dc3       333.524704
# 1          brute       423.633814
# 2     radix sort       639.555931
# 3  counting sort       763.993979
# 50 letters:
# ...

# %% [markdown]
# ## Extra Large Test Case (10000 <= n <= 100000)

# %%
perform_tests(n=100000)
# Out:
# 1 letters:
#        algorithm  total time (ms)
# 0          brute       607.291460
# 1            dc3      5052.549601
# 2  counting sort      7192.072868
# 3     radix sort     11620.452881
# 2 letters:
#        algorithm  total time (ms)
# 0            dc3      4935.740709
# 1     radix sort     11806.773186
# 2  counting sort     15319.074154
# 3          brute     16200.632334
# 5 letters:
#        algorithm  total time (ms)
# 0            dc3      5600.275993
# 1          brute      9486.947298
# 2     radix sort     10110.352755
# 3  counting sort     16149.561405
# 10 letters:
#        algorithm  total time (ms)
# 0            dc3      4246.793985
# 1          brute      7302.990198
# 2     radix sort     10121.679783
# 3  counting sort     15718.585253
# 26 letters:
#        algorithm  total time (ms)
# 0            dc3      4954.993963
# 1          brute      6447.684288
# 2     radix sort      8255.187035
# 3  counting sort     17243.300200
# 50 letters:
# ...
